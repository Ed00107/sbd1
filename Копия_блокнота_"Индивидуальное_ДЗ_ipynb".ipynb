# %% [markdown]
# <a href="https://colab.research.google.com/github/Ed00107/sbd1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%98%D0%BD%D0%B4%D0%B8%D0%B2%D0%B8%D0%B4%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5_%D0%94%D0%97_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Большое ДЗ #3

# %% [markdown]
# # Часть 1

# %% [markdown]
# Представим, что вы продуктовый аналитик в интернет-магазине Ascent: [ссылка](http://shop-stdata.tilda.ws/). Вам написал продуктовый менеджер:
#
# ![image](https://sun9-58.userapi.com/impg/oVu8ooeRJ7mnQW-pa63fJJIQzRjHQwujdCqQPg/RL9gWIzmbZw.jpg?size=2090x464&quality=95&sign=744a122eca2caf2da8a978fb290782bd&type=album)
#
# Ваша задача – придумать как можно больше гипотез о том, что можно улучшить в интернет-магазине Ascent. Совет: будьте внимательны к каждой детали :)

# %% [markdown]
# **Ваши гипотезы:**
#
# №Добавить Личные кабинеты , установить кнопку регистрации в правом верхнем углу (установить быстрый визуальный контакт)
#
# 1. ...Акции и скидки! Создать систему кэшбэка!
# 2. ...Включить отзывы к товарам  ! Наполнить поверхностными отзывами каждый товар. Количество и содержательность отзывов в зависит от цен и теоретически возможного спроса !
# 3. ...Увеличить  ассортимент. Чем больще товаров , тем больше выбора! Благодаря выбору будет больше конверсии !
# 4. ...Добавить функцию подсчета просмотров каждого товара.Для начала использовать кейс  , когда уникальность посетителей не учитывается , а время , за которое считываются просмотры, не ограничено. Это создаст визульный топ список для покупателей.А уже при достижении достаточного количества просмотров можно переключиться на кейс с уникальными посетителями!
# 5. Создать функцию по рассылке новостных оповещений.(Новые модели,Снижение цены,Скидки...выиграть промокод)!
# 6. ... Выбрать перспективные каналы трафика и установить чат бот!
# 7. ...Добавить поп_апы с ссылкой на иные товары из магазина!

# %% [markdown]
# # Часть 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Выполните клетку ниже

# %%
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv .
# Out:
# --2022-12-20 15:52:21--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv.1’
#
# titanic.csv.1       100%[===================>]  43.19K  --.-KB/s    in 0.1s
#
# 2022-12-20 15:52:22 (304 KB/s) - ‘titanic.csv.1’ saved [44225/44225]
#
# --2022-12-20 15:52:22--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2022-12-20 15:52:22--
# Total wall clock time: 0.5s
# Downloaded: 1 files, 43K in 0.1s (304 KB/s)

# %% [markdown]
# ## Задание 1
# Прочитайте файл в датафрейм, так, чтобы появились корректные колонки без каких-либо дополнительных действий, и отобразите первые 5 строчек

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d2384d5e-ed39-4a7f-94dc-4ef707b7efa9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2384d5e-ed39-4a7f-94dc-4ef707b7efa9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df = pd.read_csv("titanic.csv") # https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
titanic = pd.read_csv ("titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# ## Задание 2
# Вывести имена всех выживших детей и их количество (у детей возраст < 18)

# %%
titanic.query('Age < 18 & Survived == 1')['Name']
# Out:
# 9           Mrs. Nicholas (Adele Achem) Nasser
# 10              Miss. Marguerite Rut Sandstrom
# 22                          Miss. Anna McGowan
# 39                  Miss. Jamila Nicola-Yarred
# 42     Miss. Simonne Marie Anne Andree Laroche
#                         ...
# 826     Mrs. Antoni (Selini Alexander) Yasbeck
# 827             Master. George Sibley Richards
# 849                   Miss. Mary Conover Lines
# 865             Master. Harold Theodor Johnson
# 871                   Miss. Adele Kiamie Najib
# Name: Name, Length: 65, dtype: object

# %% [markdown]
# ## Задание 3
# Сделайте индексом колонку Name

# %%
titanic.set_index('Name')
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Mr. Owen Harris Braund                                     0       3    male
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1  female
# Miss. Laina Heikkinen                                      1       3  female
# Mrs. Jacques Heath (Lily May Peel) Futrelle                1       1  female
# Mr. William Henry Allen                                    0       3    male
# ...                                                      ...     ...     ...
# Rev. Juozas Montvila                                       0       2    male
# Miss. Margaret Edith Graham                                1       1  female
# Miss. Catherine Helen Johnston                             0       3  female
# Mr. Karl Howell Behr                                       1       1    male
# Mr. Patrick Dooley                                         0       3    male
#
# ...

# %% [markdown]
# ## Задание 4
# Выберите возраст, и колонку Survived всех людей у которых в имени есть слово Henry

# %%
titanic.loc[df['Name'].str.contains('Henry'), ['Age','Survived']]

# %% [markdown]
# ## Задание 5
# Посчитайте среднюю выживаемость в зависимости от приставки в имени.
#
# *Подсказка: приставка -- первое слово, или то слово, которое обозначается через точку (см результат для Henry). Воспользуйтесь groupby и строковыми методами работы .str*

# %%
titanic_prefix = titanic['Name'].str.split('.',1,expand=True)
titanic.groupby(titanic_prefix[0])['Survived'].mean()
# Out:
# 0
# Capt            0.000000
# Col             0.500000
# Don             0.000000
# Dr              0.428571
# Jonkheer        0.000000
# Lady            1.000000
# Major           0.500000
# Master          0.575000
# Miss            0.697802
# Mlle            1.000000
# Mme             1.000000
# Mr              0.157895
# Mrs             0.792000
# Ms              1.000000
# Rev             0.000000
# Sir             1.000000
# the Countess    1.000000
# Name: Survived, dtype: float64

# %%
titanic.groupby(
  titanic['Name'].str.extract(r'(?<=[, ])(?P<Pref>\w+)\.').squeeze()
)['Survived'].mean()
# Out:
# Pref
# Countess    1.0
# L           1.0
# Name: Survived, dtype: float64

# %% [markdown]
# ## Задание 6
# Постройте общее распределение выживших и невыживших

# %%
not_survived = titanic[titanic['Survived']==0]

sns.factorplot('Survived', data=titanic, kind='count')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Задание 7
# Постройте еще какой-нибудь интересный по вашему мнению график, приведенный в материале выше. Объясните почему вы построили именно его.

# %%
#Гистограмма распределения по возрасту выживших и пострадавших
sns.FacetGrid(titanic,col='Survived').map(plt.hist,'Age',bins=20,)

# %% [markdown]
# ## Задание 8
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя метод pivot_table

# %%
# ваш код тут
titanic.pivot_table(values='Survived', index='Pclass', columns='Sex', aggfunc=np.mean).mul(100)
# Out:
# Sex        female       male
# Pclass
# 1       96.808511  36.885246
# 2       92.105263  15.740741
# 3       50.000000  13.702624
